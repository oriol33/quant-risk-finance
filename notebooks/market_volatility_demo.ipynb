# %%
import pandas as pd
import numpy as np
from risk_metrics.market import annualized_volatility

returns = pd.Series(np.random.normal(0, 0.01, 252))
annualized_volatility(returns)
# Out:
# np.float64(0.16538172466477072)

# %%
cd '/Users/oriolgairinarmengol/Documents/quant-risk-finance/src'
# Out:
# /Users/oriolgairinarmengol/Documents/quant-risk-finance/src

# %%
pwd
# Out:
# '/Users/oriolgairinarmengol/Documents/quant-risk-finance/notebooks/public'

# %%
import os
import sys

print(os.getcwd())
print(sys.executable)
# Out:
# /Users/oriolgairinarmengol/Documents/quant-risk-finance/notebooks/public
# /Users/oriolgairinarmengol/Documents/quant-risk-finance/.venv/bin/python
